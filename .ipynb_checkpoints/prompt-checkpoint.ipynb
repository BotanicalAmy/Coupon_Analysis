# %% [markdown]
# ### Will a Customer Accept the Coupon?
#
# **Context**
#
# Imagine driving through town and a coupon is delivered to your cell phone for a restaraunt near where you are driving. Would you accept that coupon and take a short detour to the restaraunt? Would you accept the coupon but use it on a sunbsequent trip? Would you ignore the coupon entirely? What if the coupon was for a bar instead of a restaraunt? What about a coffee house? Would you accept a bar coupon with a minor passenger in the car? What about if it was just you and your partner in the car? Would weather impact the rate of acceptance? What about the time of day?
#
# Obviously, proximity to the business is a factor on whether the coupon is delivered to the driver or not, but what are the factors that determine whether a driver accepts the coupon once it is delivered to them? How would you determine whether a driver is likely to accept a coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
# This data comes to us from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under \\$20), coffee houses, carry out & take away, bar, and more expensive restaurants (\\$20 - \\$50).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
# Keep in mind that these values mentioned below are average values.
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ### Problems
#
# Use the prompts below to get started with your data analysis.
#
# 1. Read in the `coupons.csv` file.

# %%
df = pd.read_csv('data/coupons.csv')

# %%
df.head(10)
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
# 5  No Urgent Place  Friend(s)   Sunny           80   6PM
# 6  No Urgent Place  Friend(s)   Sunny           55   2PM
# 7  No Urgent Place     Kid(s)   Sunny           80  10AM
# 8  No Urgent Place     Kid(s)   Sunny           80  10AM
# 9  No Urgent Place     Kid(s)   Sunny           80  10AM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
# 5        Restaurant(<20)         2h  Female  21  Unmarried partner  ...
# 6  Carry out & Take away         1d  Female  21  Unmarried partner  ...
# 7        Restaurant(<20)         2h  Female  21  Unmarried partner  ...
# 8  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 9                    Bar         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# 1        never       NaN                  4~8              1~3
# 2        never       NaN                  4~8              1~3
# 3        never       NaN                  4~8              1~3
# 4        never       NaN                  4~8              1~3
# 5        never       NaN                  4~8              1~3
# 6        never       NaN                  4~8              1~3
# 7        never       NaN                  4~8              1~3
# 8        never       NaN                  4~8              1~3
# 9        never       NaN                  4~8              1~3
#
#   toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min direction_same  \
# 0                1                 0                 0              0
# 1                1                 0                 0              0
# 2                1                 1                 0              0
# 3                1                 1                 0              0
# 4                1                 1                 0              0
# 5                1                 1                 0              0
# 6                1                 1                 0              0
# 7                1                 1                 0              0
# 8                1                 1                 0              0
# 9                1                 1                 0              0
#
#   direction_opp  Y
# 0             1  1
# 1             1  0
# 2             1  1
# 3             1  0
# 4             1  0
# 5             1  1
# 6             1  1
# 7             1  1
# 8             1  1
# 9             1  0
#
# [10 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
#  15  Bar                   12577 non-null  object
#  16  CoffeeHouse           12467 non-null  object
#  17  CarryAway             12533 non-null  object
#  18  RestaurantLessThan20  12554 non-null  object
#  19  Restaurant20To50      12495 non-null  object
#  20  toCoupon_GEQ5min      12684 non-null  int64
#  21  toCoupon_GEQ15min     12684 non-null  int64
#  22  toCoupon_GEQ25min     12684 non-null  int64
#  23  direction_same        12684 non-null  int64
#  24  direction_opp         12684 non-null  int64
#  25  Y                     12684 non-null  int64
# dtypes: int64(8), object(18)
# memory usage: 2.5+ MB

# %% [markdown]
# 2. Investigate the dataset for missing or problematic data.

# %%
nan_count = df.isna().sum()
nan_count
# Out:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64

# %%
df_investigate = df[['car','Bar','CoffeeHouse','CarryAway','RestaurantLessThan20', 'Restaurant20To50']]
df_investigate.head(25)
# Out:
#     car    Bar CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50
# 0   NaN  never       never       NaN                  4~8              1~3
# 1   NaN  never       never       NaN                  4~8              1~3
# 2   NaN  never       never       NaN                  4~8              1~3
# 3   NaN  never       never       NaN                  4~8              1~3
# 4   NaN  never       never       NaN                  4~8              1~3
# 5   NaN  never       never       NaN                  4~8              1~3
# 6   NaN  never       never       NaN                  4~8              1~3
# 7   NaN  never       never       NaN                  4~8              1~3
# 8   NaN  never       never       NaN                  4~8              1~3
# 9   NaN  never       never       NaN                  4~8              1~3
# 10  NaN  never       never       NaN                  4~8              1~3
# 11  NaN  never       never       NaN                  4~8              1~3
# 12  NaN  never       never       NaN                  4~8              1~3
# 13  NaN  never       never       NaN                  4~8              1~3
# 14  NaN  never       never       NaN                  4~8              1~3
# 15  NaN  never       never       NaN                  4~8              1~3
# 16  NaN  never       never       NaN                  4~8              1~3
# 17  NaN  never       never       NaN                  4~8              1~3
# 18  NaN  never       never       NaN                  4~8              1~3
# 19  NaN  never       never       NaN                  4~8              1~3
# 20  NaN  never       never       NaN                  4~8              1~3
# 21  NaN  never       never       NaN                  4~8              1~3
# 22  NaN  never       less1       4~8                  4~8            less1
# 23  NaN  never       less1       4~8                  4~8            less1
# 24  NaN  never       less1       4~8                  4~8            less1

# %%
#dropped the car column because it did not contain useful data (mostly nan)
df = df.drop('car', axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  Bar                   12577 non-null  object
#  15  CoffeeHouse           12467 non-null  object
#  16  CarryAway             12533 non-null  object
#  17  RestaurantLessThan20  12554 non-null  object
#  18  Restaurant20To50      12495 non-null  object
#  19  toCoupon_GEQ5min      12684 non-null  int64
#  20  toCoupon_GEQ15min     12684 non-null  int64
#  21  toCoupon_GEQ25min     12684 non-null  int64
#  22  direction_same        12684 non-null  int64
#  23  direction_opp         12684 non-null  int64
#  24  Y                     12684 non-null  int64
# dtypes: int64(8), object(17)
# memory usage: 2.4+ MB

# %%
#confirming the nan values equal the missing number of rows to add up to 12684
# df_investigate_2 = df[['Bar','CoffeeHouse','CarryAway','RestaurantLessThan20', 'Restaurant20To50']]
# df_investigate_2.head(25)

df['coupon'].unique()
# df['Bar'].unique()
# df['Bar'].value_counts()
# df['Bar'].isnull().sum() 

# df['CoffeeHouse'].unique()
# df['CoffeeHouse'].value_counts()
# df['CoffeeHouse'].isnull().sum()

# df['CarryAway'].unique()
# df['CarryAway'].value_counts()
# df['CarryAway'].isnull().sum()

# df['RestaurantLessThan20'].unique()
# df['RestaurantLessThan20'].value_counts()
# df['RestaurantLessThan20'].isnull().sum()

# df['Restaurant20To50'].unique()
# df['Restaurant20To50'].value_counts()
# df['Restaurant20To50'].isnull().sum()
# Out:
# array(['Restaurant(<20)', 'Coffee House', 'Carry out & Take away', 'Bar',
#        'Restaurant(20-50)'], dtype=object)

# %% [markdown]
# 3. Decide what to do about your missing data -- drop, replace, other...

# %%
df_filled = df.fillna('never')
df_filled.head(50)
df_filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  Bar                   12684 non-null  object
#  15  CoffeeHouse           12684 non-null  object
#  16  CarryAway             12684 non-null  object
#  17  RestaurantLessThan20  12684 non-null  object
#  18  Restaurant20To50      12684 non-null  object
#  19  toCoupon_GEQ5min      12684 non-null  int64
#  20  toCoupon_GEQ15min     12684 non-null  int64
#  21  toCoupon_GEQ25min     12684 non-null  int64
#  22  direction_same        12684 non-null  int64
#  23  direction_opp         12684 non-null  int64
#  24  Y                     12684 non-null  int64
# dtypes: int64(8), object(17)
# memory usage: 2.4+ MB

# %% [markdown]
# 4. What proportion of the total observations chose to accept the coupon?

# %%
#determoine percentages of coupon acceptance
coupon_percent_yes = (sum(df_filled.Y == 1)/df_filled['Y'].count())*100
coupon_percent_no = (sum(df_filled.Y == 0)/df_filled['Y'].count())*100
print(f"{coupon_percent_yes.round(2)}% of customers accepted the coupon")
print(f"{coupon_percent_no.round(2)}% of customers rejected the coupon")
# Out:
# 56.84% of customers accepted the coupon
# 43.16% of customers rejected the coupon

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
#visualizing the coupon acceptance count
sns.countplot(data= df_filled, x='Y', hue='Y')
plt.legend(loc='upper left', labels=['No', 'Yes'])
plt.title('Customer Coupon Acceptance')
plt.xlabel('Coupon Acceptance')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
#histogram of temperatures
sns.histplot(data=df_filled, x='temperature')
plt.show()

#looking at the unique temperatures after seeing this distribution
#clearly a simple selection option instead of a precise recording
# unique_temps = df['temperature'].unique()
# print(unique_temps)

# %%
df_filled.replace({'temperature':{55:'mild', 80:'hot', 30:'cold'}}, inplace = True)
df_filled.head()
# Out:
#        destination  passanger weather temperature  time  \
# 0  No Urgent Place      Alone   Sunny        mild   2PM
# 1  No Urgent Place  Friend(s)   Sunny         hot  10AM
# 2  No Urgent Place  Friend(s)   Sunny         hot  10AM
# 3  No Urgent Place  Friend(s)   Sunny         hot   2PM
# 4  No Urgent Place  Friend(s)   Sunny         hot   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never     never                  4~8              1~3
# 1        never     never                  4~8              1~3
# 2        never     never                  4~8              1~3
# 3        never     never                  4~8              1~3
# 4        never     never                  4~8              1~3
#
#   toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min direction_same  \
# 0                1                 0                 0              0
# 1                1                 0                 0              0
# 2                1                 1                 0              0
# 3                1                 1                 0              0
# 4                1                 1                 0              0
#
#   direction_opp  Y
# 0             1  1
# 1             1  0
# 2             1  1
# 3             1  0
# 4             1  0
#
# [5 rows x 25 columns]

# %%
#histogram of temperatures, made prettier and using new cold, mild, hot labels
fig = px.histogram(df_filled, x='temperature', color='temperature',
                  color_discrete_map={
        'mild': '#3cb878',
        'hot': '#f26c4f',
        'cold': '#5674b9'
    })
fig.update_xaxes(categoryorder='array', categoryarray= ['cold','mild','hot'])
fig.update_layout(
    xaxis_title="Temperature",
    yaxis_title="Count",
    title="Weather during coupon promotion")
fig.show()
# Out:
# <div>                            <div id="d5a4b36f-e6b5-46b1-8986-2393ebd4b36d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5a4b36f-e6b5-46b1-8986-2393ebd4b36d")) {                    Plotly.newPlot(                        "d5a4b36f-e6b5-46b1-8986-2393ebd4b36d",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"temperature=%{x}<br>count=%{y}<extra></extra>","legendgroup":"mild","marker":{"color":"#3cb878","pattern":{"shape":""}},"name":"mild","offsetgroup":"mild","orientation":"v","showlegend":true,"x":["mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mild","mi ...

# %%
#comparing histograms side by side to observe that during hot weather
#customers are less likely to accept the coupon
sns.histplot(df_filled, x='temperature', hue='Y', multiple="dodge", shrink=.8)
plt.legend(loc='upper left', labels=['No', 'Yes'])
plt.title('Customer Coupon Acceptance by Weather')
plt.xlabel('Weather')
plt.ylabel('Coupon Acceptance Count')
plt.show()

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Now, we will lead you through an exploration of just the bar related coupons.
#
# 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
bar_coupons = df_filled.query("coupon == 'Bar'")
bar_coupons.head(25)
# Out:
#          destination  passanger weather temperature  time coupon expiration  \
# 9    No Urgent Place     Kid(s)   Sunny         hot  10AM    Bar         1d
# 13              Home      Alone   Sunny        mild   6PM    Bar         1d
# 17              Work      Alone   Sunny        mild   7AM    Bar         1d
# 24   No Urgent Place  Friend(s)   Sunny         hot  10AM    Bar         1d
# 35              Home      Alone   Sunny        mild   6PM    Bar         1d
# 39              Work      Alone   Sunny        mild   7AM    Bar         1d
# 46   No Urgent Place  Friend(s)   Sunny         hot  10AM    Bar         1d
# 57              Home      Alone   Sunny        mild   6PM    Bar         1d
# 61              Work      Alone   Sunny        mild   7AM    Bar         1d
# 75   No Urgent Place     Kid(s)   Sunny         hot  10AM    Bar         1d
# 79              Home      Alone   Sunny        mild   6PM    Bar         1d
# 83              Work      Alone   Sunny        mild   7AM    Bar         1d
# 90   No Urgent Place  Friend(s)   Sunny         hot  10AM    Bar         1d
# 101             Home      Alone   Sunny        mild   6PM    Bar         1d
# 105             Work      Alone   Sunny        mild   7AM    Bar         1d
# 112  No Urgent Place  Friend(s)   Sunny         hot  10AM    Bar         1d
# 123             Home      Alone   Sunny        mild   6PM    Bar         1d
# 127             Work      Alone   Sunny        mild   7AM    Bar         1d
# 141  No Urgent Place     Kid(s)   Sunny         hot  10AM    Bar         1d
# 145             Home      Alone   Sunny        mild   6PM    Bar         1d
# 149             Work      Alone   Sunny        mild   7AM    Bar         1d
# 156  No Urgent Place  Friend(s)   Sunny         hot  10AM    Bar         1d
# 167             Home      Alone   Sunny        mild   6PM    Bar         1d
# 171             Work      Alone   Sunny        mild   7AM    Bar         1d
# 178  No Urgent Place  Friend(s)   Sunny         hot  10AM    Bar         1d
#
#      gender age      maritalStatus  ...  CoffeeHouse CarryAway  \
# 9    Female  21  Unmarried partner  ...        never     never
# 13   Female  21  Unmarried partner  ...        never     never
# 17   Female  21  Unmarried partner  ...        never     never
# 24     Male  21             Single  ...        less1       4~8
# 35     Male  21             Single  ...        less1       4~8
# 39     Male  21             Single  ...        less1       4~8
# 46     Male  46             Single  ...          4~8       1~3
# 57     Male  46             Single  ...          4~8       1~3
# 61     Male  46             Single  ...          4~8       1~3
# 75     Male  46    Married partner  ...          1~3       1~3
# 79     Male  46    Married partner  ...          1~3       1~3
# 83     Male  46    Married partner  ...          1~3       1~3
# 90     Male  21             Single  ...        less1       1~3
# 101    Male  21             Single  ...        less1       1~3
# 105    Male  21             Single  ...        less1       1~3
# 112    Male  26  Unmarried partner  ...          gt8       4~8
# 123    Male  26  Unmarried partner  ...          gt8       4~8
# 127    Male  26  Unmarried partner  ...          gt8       4~8
# 141  Female  26    Married partner  ...        less1       gt8
# 145  Female  26    Married partner  ...        less1       gt8
# 149  Female  26    Married partner  ...        less1       gt8
# 156    Male  26             Single  ...          gt8       gt8
# 167    Male  26             Single  ...          gt8       gt8
# 171    Male  26             Single  ...          gt8       gt8
# 178  Female  26             Single  ...          1~3       4~8
#
#     RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min toCoupon_GEQ15min  \
# 9                    4~8              1~3                1                 1
# 13                   4~8              1~3                1                 0
# 17                   4~8              1~3                1                 1
# 24                   4~8            less1                1                 0
# 35                   4~8            less1                1                 0
# 39                   4~8            less1                1                 1
# 46                   1~3            never                1                 0
# 57                   1~3            never                1                 0
# 61                   1~3            never                1                 1
# 75                   1~3            less1                1                 1
# 79                   1~3            less1                1                 0
# 83                   1~3            less1                1                 1
# 90                 less1              1~3                1                 0
# 101                less1              1~3                1                 0
# 105                less1              1~3                1                 1
# 112                  1~3            less1                1                 0
# 123                  1~3            less1                1                 0
# 127                  1~3            less1                1                 1
# 141                  4~8            never                1                 1
# 145                  4~8            never                1                 0
# 149                  4~8            never                1                 1
# 156                  gt8              gt8                1                 0
# 167                  gt8              gt8                1                 0
# 171                  gt8              gt8                1                 1
# 178                  1~3            less1                1                 0
#
#     toCoupon_GEQ25min direction_same direction_opp  Y
# 9                   0              0             1  0
# 13                  0              1             0  1
# 17                  1              0             1  0
# 24                  0              0             1  1
# 35                  0              1             0  1
# 39                  1              0             1  1
# 46                  0              0             1  0
# 57                  0              1             0  0
# 61                  1              0             1  0
# 75                  0              0             1  1
# 79                  0              1             0  1
# 83                  1              0             1  1
# 90                  0              0             1  1
# 101                 0              1             0  1
# 105                 1              0             1  0
# 112                 0              0             1  1
# 123                 0              1             0  1
# 127                 1              0             1  1
# 141                 0              0             1  0
# 145                 0              1             0  0
# 149                 1              0             1  0
# 156                 0              0             1  1
# 167                 0              1             0  1
# 171                 1              0             1  1
# 178                 0              0             1  0
#
# [25 rows x 25 columns]

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %%
bar_accepted = (sum(bar_coupons.Y == 1)/bar_coupons['Y'].count())*100
print(f"{bar_accepted.round(2)}% of the bar coupons were accepted")
# Out:
# 41.0% of the bar coupons were accepted

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
# df_filled['Bar'].unique()
# those who accepted bar coupons based on bar visits
bar_3_less = bar_coupons.query("Bar in ('never', 'less1', '1~3')")
bar_3_more = bar_coupons.query("Bar in ('4~8', 'gt8')")

#checking my data
# print(bar_coupons['Y'].count())
# print(sum(bar_3_less.Y == 1))
# print(sum(bar_3_more.Y == 1))

bar_3_less_accepted = (sum(bar_3_less.Y == 1)/bar_3_less['Y'].count())*100
bar_3_more_accepte = (sum(bar_3_more.Y == 1)/bar_3_more['Y'].count())*100

print(f"{bar_3_less_accepted.round(2)}% of those who visited bars 3 times or less and accepted the bar coupon")
print(f"{bar_3_more_accepted.round(2)}% of those who visited bars 3 times or more and accepted the bar coupon")
# Out:
# 37.07% of those who visited bars 3 times or less and accepted the bar coupon
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0l/sq6hznv903d9tg6l22_ht29w0000gn/T/ipykernel_24980/799928590.py in <module>
#      13
#      14 print(f"{bar_3_less_accepted.round(2)}% of those who visited bars 3 times or less and accepted the bar coupon")
# ---> 15 print(f"{bar_3_more_accepted.round(2)}% of those who visited bars 3 times or more and accepted the bar coupon")
#
# NameError: name 'bar_3_more_accepted' is not defined

# %%
# those who accepted any coupons based on their bar visits
all_coupon_bar_3_less = df_filled.query("Bar in ('never', 'less1', '1~3')")
all_coupon_bar_3_more = df_filled.query("Bar in ('4~8', 'gt8')")

ap_bar_3_less = (sum(bar_3_less.Y == 1)/sum(df_filled.Y==1))*100
ap_bar_3_more = (sum(bar_3_more.Y == 1)/sum(df_filled.Y==1))*100

all_coupon_bar_3_less_accepted = round(ap_bar_3_less, 2)
all_coupon_bar_3_more_accepted = round(ap_bar_3_more, 2)

print(f"{all_coupon_bar_3_less_accepted:0.2f}% of those who visited bars 3 times or less who accepted any coupon")
print(f"{all_coupon_bar_3_more_accepted:0.2f}% of those who visited bars 3 times or more who accepted any coupon")

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
print(df_filled['age'].unique())

over_25 = ['46','26','31', '36','41', '50plus']
bar_once_month = ['1~3','4~8','gt8']
bar_over_25 = df_filled.query('Bar in @bar_once_month and age in @over_25')
# Out:
# ['21' '46' '26' '31' '41' '50plus' '36' 'below21']

# %% [markdown]
# 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %% [markdown]
# 6. Compare the acceptance rates between those drivers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %% [markdown]
# 7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.

# %%
print(df_filled['coupon'].unique())
print(df_filled['income'].unique())


bar = df_filled.query("coupon == 'Bar'")
take_out = df_filled.query("coupon == 'Carry out & Take away'")
casual_restaurant = df_filled.query("coupon == 'Restaurant(<20)'")
upscale_restaurant = df_filled.query("coupon == 'Restaurant(20-50)'")
# Out:
# ['Restaurant(<20)' 'Coffee House' 'Carry out & Take away' 'Bar'
#  'Restaurant(20-50)']
# ['$37500 - $49999' '$62500 - $74999' '$12500 - $24999' '$75000 - $87499'
#  '$50000 - $62499' '$25000 - $37499' '$100000 or More' '$87500 - $99999'
#  'Less than $12500']

# %%
#setting the order for the income ranges
df_filled.income = pd.Categorical(df.income, 
                      categories=['Less than $12500', '$12500 - $24999','$25000 - $37499','$37500 - $49999',
                                 '$50000 - $62499','$62500 - $74999', '$75000 - $87499', '$87500 - $99999', '$100000 or More'],
                      ordered=True)

#histogram to compare coupon acceptance by income level
sns.histplot(df_filled, x='income', hue='Y', multiple="dodge")
plt.legend(loc='upper left', labels=['No', 'Yes'])
plt.title('Coupon Acceptance by Income')
plt.xticks(rotation=45)
plt.xlabel('Income')
plt.ylabel('Coupon Acceptance Count')
plt.show()
